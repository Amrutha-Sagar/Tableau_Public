# %% [markdown]
# ## Task:
# ### You are the business owner of the retail firm and want to see how your company is performing. You are interested in finding out the weak areas where you can work to make more profit. What all business problems you can derive by looking into the data?

# %%
from pyforest import *

# %%
df=pd.read_csv('SampleSuperstore.csv')
df.head()
# Out:
#         Ship Mode    Segment        Country             City  ...     Sales  Quantity Discount    Profit
# 0    Second Class   Consumer  United States        Henderson  ...  261.9600         2     0.00   41.9136
# 1    Second Class   Consumer  United States        Henderson  ...  731.9400         3     0.00  219.5820
# 2    Second Class  Corporate  United States      Los Angeles  ...   14.6200         2     0.00    6.8714
# 3  Standard Class   Consumer  United States  Fort Lauderdale  ...  957.5775         5     0.45 -383.0310
# 4  Standard Class   Consumer  United States  Fort Lauderdale  ...   22.3680         2     0.20    2.5164
#
# [5 rows x 13 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
# Ship Mode       9994 non-null object
# Segment         9994 non-null object
# Country         9994 non-null object
# City            9994 non-null object
# State           9994 non-null object
# Postal Code     9994 non-null int64
# Region          9994 non-null object
# Category        9994 non-null object
# Sub-Category    9994 non-null object
# Sales           9994 non-null float64
# Quantity        9994 non-null int64
# Discount        9994 non-null float64
# Profit          9994 non-null float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
df.shape
# Out:
# (9994, 13)

# %%
df.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
data=df.select_dtypes(include='object')
for i in data.columns:
    print(i)
    print(data[i].value_counts())
    print()
# Out:
# Ship Mode
# Standard Class    5968
# Second Class      1945
# First Class       1538
# Same Day           543
# Name: Ship Mode, dtype: int64
#
# Segment
# Consumer       5191
# Corporate      3020
# Home Office    1783
# Name: Segment, dtype: int64
#
# Country
# United States    9994
# Name: Country, dtype: int64
#
# City
# New York City     915
# Los Angeles       747
# Philadelphia      537
# San Francisco     510
# Seattle           428
#                  ...
# Atlantic City       1
# Jefferson City      1
# Tinley Park         1
# Grand Island        1
# Saint Peters        1
# Name: City, Length: 531, dtype: int64
#
# State
# California              2001
# New York                1128
# Texas                    985
# Pennsylvania             587
# Washington               506
# Illinois                 492
# Ohio                     469
# Florida                  383
# Michigan                 255
# North Carolina           249
# Arizona                  224
# ...

# %% [markdown]
# Inferences:
# 1. No missing values with 9000+ data
# 2. Most of the features are categorical features
# 3. Sample store delivery methods and different charges are mentioned which needs to be studied
#
# Lets understand the variables
# 1. Shipmode: It has 4 modes of shipping, standard, second class and Same day. Very less people opt for same day delivery even if its a superstore. Standard shipment is most opted.
# 2. Segment: Store mostly attracts consumers other than corporate/home office which accounts for large sale capacity.
# 3. Shipment: Shipping is done for more than 500 places within US.Shipping Charges must affect.
# 4. Category: Maximum sales from office supplies as corporate and home office are one of the customers. Furniture and Technology related items are sold equally.

# %%
df.select_dtypes(include=['int64','float64'])
# Out:
#       Postal Code     Sales  Quantity  Discount    Profit
# 0           42420  261.9600         2      0.00   41.9136
# 1           42420  731.9400         3      0.00  219.5820
# 2           90036   14.6200         2      0.00    6.8714
# 3           33311  957.5775         5      0.45 -383.0310
# 4           33311   22.3680         2      0.20    2.5164
# ...           ...       ...       ...       ...       ...
# 9989        33180   25.2480         3      0.20    4.1028
# 9990        92627   91.9600         2      0.00   15.6332
# 9991        92627  258.5760         2      0.20   19.3932
# 9992        92627   29.6000         4      0.00   13.3200
# 9993        92683  243.1600         2      0.00   72.9480
#
# [9994 rows x 5 columns]

# %% [raw]
# Observation:- As we have state and city information, dropping postal code column. Dropping country as its repitetion.

# %%
df.drop(['Postal Code'],1,inplace=True)
df.drop(['Country'],1,inplace=True)

# %% [raw]
# Inference: As we Selling price and discount, Cost price for each can be calculated to find out profit percentage

# %%
discount=df['Discount']+1
df['Cost Price']=((df['Sales']-df['Profit'])/df['Quantity'])*discount

# %%
df.head()
# Out:
#         Ship Mode    Segment             City       State Region  ...     Sales Quantity  Discount    Profit  Cost Price
# 0    Second Class   Consumer        Henderson    Kentucky  South  ...  261.9600        2      0.00   41.9136  110.023200
# 1    Second Class   Consumer        Henderson    Kentucky  South  ...  731.9400        3      0.00  219.5820  170.786000
# 2    Second Class  Corporate      Los Angeles  California   West  ...   14.6200        2      0.00    6.8714    3.874300
# 3  Standard Class   Consumer  Fort Lauderdale     Florida  South  ...  957.5775        5      0.45 -383.0310  388.776465
# 4  Standard Class   Consumer  Fort Lauderdale     Florida  South  ...   22.3680        2      0.20    2.5164   11.910960
#
# [5 rows x 12 columns]

# %%
df.to_csv('cleaned_samplestore.csv')
